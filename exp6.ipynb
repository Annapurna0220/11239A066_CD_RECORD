# %% [markdown]
# <a href="https://colab.research.google.com/github/Annapurna0220/11239A066_CD_RECORD/blob/main/exp6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
ops = {"+", "-", "*", "/", "=", "==", "!=", ">", "<", ">=", "<="}

expr = input("Enter expression: ").split()

for i in expr:
    print(i, "-> Operator" if i in ops else "-> Not Operator")
# Out:
# Enter expression: +
# + -> Operator
