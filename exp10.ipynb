# %% [markdown]
# <a href="https://colab.research.google.com/github/Annapurna0220/11239A066_CD_RECORD/blob/main/exp10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# a) Restaurant Billing System

# %%
text = input("Enter Restaurant Billing Lexeme:\n")

# Generate tokens (split by space)
tokens = text.split()

print("Tokens:")
for t in tokens:
    print(t)
# Out:
# Enter Restaurant Billing Lexeme:
# Pizza 2 300 Coke 1 50 Total 650
# Tokens:
# Pizza
# 2
# 300
# Coke
# 1
# 50
# Total
# 650

# %% [markdown]
# b) Car Rental System

# %%
text = input("Enter Car Rental Lexeme:\n")

# Generate tokens (split by space)
tokens = text.split()

print("Tokens:")
for t in tokens:
    print(t)
# Out:
# Enter Car Rental Lexeme:
# Car BMW Days 3 Rate 2000 Total 6000
# Tokens:
# Car
# BMW
# Days
# 3
# Rate
# 2000
# Total
# 6000
