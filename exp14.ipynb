# %% [markdown]
# <a href="https://colab.research.google.com/github/Annapurna0220/11239A066_CD_RECORD/blob/main/exp14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# a) Online Shopping Price Calculation

# %%
input_str = input("Enter expression: ") + "$"
stack = ""

print("Stack\tInput\tAction")

while input_str:
    stack += input_str[0]
    input_str = input_str[1:]
    print(stack, "\t", input_str, "\tShift")

    if stack in ["id", "E+E", "E*E"]:
        stack = "E"
        print(stack, "\t", input_str, "\tReduce")

if stack == "E$":
    print("Accepted")
else:
    print("Rejected")
# Out:
# Enter expression: ie
# Stack	Input	Action
# i 	 e$ 	Shift
# ie 	 $ 	Shift
# ie$ 	  	Shift
# Rejected

# %% [markdown]
# b) Bank Interest Calculation

# %%
input_str = input("Enter expression: ") + "$"
stack = ""

print("Stack\tInput\tAction")

while input_str:
    stack += input_str[0]
    input_str = input_str[1:]
    print(stack, "\t", input_str, "\tShift")

    if stack in ["id", "E+E", "E*E"]:
        stack = "E"
        print(stack, "\t", input_str, "\tReduce")

if stack == "E$":
    print("Accepted")
else:
    print("Rejected")
# Out:
# Enter expression: ie
# Stack	Input	Action
# i 	 e$ 	Shift
# ie 	 $ 	Shift
# ie$ 	  	Shift
# Rejected
