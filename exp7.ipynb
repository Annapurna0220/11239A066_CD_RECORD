# %% [markdown]
# <a href="https://colab.research.google.com/github/Annapurna0220/11239A066_CD_RECORD/blob/main/exp7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# a) Restaurant Order Code

# %%
text = input("Enter Restaurant Order Code: ")

letters = digits = spaces = special = 0

for ch in text:
    if ch.isalpha():
        letters += 1
    elif ch.isdigit():
        digits += 1
    elif ch.isspace():
        spaces += 1
    else:
        special += 1

print("Letters:", letters)
print("Digits:", digits)
print("Spaces:", spaces)
print("Special Characters:", special)
# Out:
# Enter Restaurant Order Code: annap1234
# Letters: 5
# Digits: 4
# Spaces: 0
# Special Characters: 0

# %% [markdown]
# b) Car Registration Input

# %%
text = input("Enter Car Registration Input: ")

letters = digits = spaces = special = 0

for ch in text:
    if ch.isalpha():
        letters += 1
    elif ch.isdigit():
        digits += 1
    elif ch.isspace():
        spaces += 1
    else:
        special += 1

print("Letters:", letters)
print("Digits:", digits)
print("Spaces:", spaces)
print("Special Characters:", special)
# Out:
# Enter Car Registration Input: TN 10 AB 1234
# Letters: 4
# Digits: 6
# Spaces: 3
# Special Characters: 0
