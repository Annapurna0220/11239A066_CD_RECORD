# %% [markdown]
# <a href="https://colab.research.google.com/github/Annapurna0220/11239A066_CD_RECORD/blob/main/exp12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# a) Delivery Route Grammar

# %%
grammar = {"S": ["road", "path"]}

print("LEADING(S):", set(grammar["S"]))
print("TRAILING(S):", set(grammar["S"]))
# Out:
# LEADING(S): {'road', 'path'}
# TRAILING(S): {'road', 'path'}

# %% [markdown]
# b) Car Assembly Line Grammar

# %%
grammar = {"S": ["engine", "body"]}

print("LEADING(S):", set(grammar["S"]))
print("TRAILING(S):", set(grammar["S"]))
# Out:
# LEADING(S): {'engine', 'body'}
# TRAILING(S): {'engine', 'body'}
