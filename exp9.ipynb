# %% [markdown]
# <a href="https://colab.research.google.com/github/Annapurna0220/11239A066_CD_RECORD/blob/main/exp9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# a) Customer Feedback File

# %%
text = input("Enter Customer Feedback:\n")

print("Lines:", len(text.split("\n")))
print("Words:", len(text.split()))
print("Characters:", len(text))
# Out:
# Enter Customer Feedback:
# nice with the outcome
# Lines: 1
# Words: 4
# Characters: 21

# %% [markdown]
# b) Coding Assignment File

# %%
text = input("Enter Coding Assignment Text:\n")

print("Lines:", len(text.split("\n")))
print("Words:", len(text.split()))
print("Characters:", len(text))
# Out:
# Enter Coding Assignment Text:
# nice treat
# Lines: 1
# Words: 2
# Characters: 10
