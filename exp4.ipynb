# %% [markdown]
# <a href="https://colab.research.google.com/github/Annapurna0220/11239A066_CD_RECORD/blob/main/exp4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Hotel Booking

# %%
text = input("Enter Hotel Booking Details:\n")
print("Lines:", len(text.split("\n")))
print("Spaces:", text.count(" "))
# Out:
# Enter Hotel Booking Details:
# there is a romm available
# Lines: 1
# Spaces: 4

# %% [markdown]
# Exam Question Paper

# %%
text = input("Enter Exam Question Paper:\n")
print("Lines:", len(text.split("\n")))
print("Spaces:", text.count(" "))
# Out:
# Enter Exam Question Paper:
# write about your self
# Lines: 1
# Spaces: 3
